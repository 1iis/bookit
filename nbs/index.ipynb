# %%
#| hide
from bookit.core import *

# %% [markdown]
# # bookit
#
# > A runtime for hyperbooks.

# %% [markdown]
# This file will become your README and also the index of your documentation.

# %% [markdown]
# ## Developer Guide

# %% [markdown]
# If you are new to using `nbdev` here are some useful pointers to get you started.

# %% [markdown]
# ### Install bookit in Development mode

# %% [markdown]
# ```sh
# # make sure bookit package is installed in development mode
# $ pip install -e .
#
# # make changes under nbs/ directory
# # ...
#
# # compile to have changes apply to bookit
# $ nbdev_prepare
# ```

# %% [markdown]
# ## Usage

# %% [markdown]
# ### Installation

# %% [markdown]
# Install latest from the GitHub [repository][repo]:
#
# ```sh
# $ pip install git+https://github.com/1iis/bookit.git
# ```
#
# or from [conda][conda]
#
# ```sh
# $ conda install -c 1iis bookit
# ```
#
# or from [pypi][pypi]
#
#
# ```sh
# $ pip install bookit
# ```
#
#
# [repo]: https://github.com/1iis/bookit
# [docs]: https://1iis.github.io/bookit/
# [pypi]: https://pypi.org/project/bookit/
# [conda]: https://anaconda.org/1iis/bookit

# %% [markdown]
# ### Documentation

# %% [markdown]
# Documentation can be found hosted on this GitHub [repository][repo]'s [pages][docs]. Additionally you can find package manager specific guidelines on [conda][conda] and [pypi][pypi] respectively.
#
# [repo]: https://github.com/1iis/bookit
# [docs]: https://1iis.github.io/bookit/
# [pypi]: https://pypi.org/project/bookit/
# [conda]: https://anaconda.org/1iis/bookit

# %% [markdown]
# ## How to use

# %% [markdown]
# Fill me in please! Don't forget code examples:

# %%
1+1
# Out:
# 2
